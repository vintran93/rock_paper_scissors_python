# %% [markdown]
# # Python Rock Paper Sciccors Game

# %%
link = 'https://www.udemy.com/course/rock-paper-scissors-python/?LSNPUBID=JVFxdTr9V80&ranEAID=JVFxdTr9V80&ranMID=39197&ranSiteID=JVFxdTr9V80-RIeANxONGX_IRS0Q5tHdjg&utm_medium=udemyads&utm_source=aff-campaign'

# %%
lose = ("The computer wins!")

win = ("You win!")

lives = 7

score = 0

draw = 0

computer_lives = 7

while True:
    print("To begin fill in the below information.")
    
    username = input("Please enter your username: ")
    
    password = input("Please enter your password: ")
    
    searchfile = open("accounts.csv",'r')
    
    for line in searchfile:
        if username and password in line:
            print("Access Granted")
            # Rock
            print("""
                _______
            ---'   ____)
                  (_____)
                  (_____)
                  (____)
            ---.__(___)
            """)

            # Paper
            print("""
                 _______
            ---'    ____)____
                       ______)
                      _______)
                     _______)
            ---.__________)
            """)

        # Scissors
        print("""
            _______
        ---'   ____)____
                  ______)
               __________)
              (____)
        ---.__(___)
        """)
        while True:
            rps = input("Choose rock, paper or scissors: ")
            import random
            computer = ("rock","paper","scissors")
            computer = random.choice(computer)
            
            # Rock if statements
            if rps == "rock" and computer == "paper":
                print("The computer chose", computer)
                print("")
                print(lose)
                print("")
                lives -= 1
            if rps == "rock" and computer == "scissors":
                print("The computer chose", computer)
                print("")
                print(win)
                print("")
                score += 1
            # Paper if statements
            if rps == "paper" and computer == "rock":
                print("The computer chose", computer)
                print("")
                print(win)
                computer_lives -= 1
                print("")
                score += 1
            if rps == "paper" and computer == "scissors":
                print("The computer chose", computer)
                print("")
                print(lose)
                print("")
                lives -= 1
            # Scissors if statements
            if rps == "scissors" and computer == "paper":
                print("The computer chose", computer)
                print("")
                print(win)
                computer_lives -= 1
                print("")
                lives -= 1
            if rps == "scissors" and computer == "rock":
                print("The computer chose", computer)
                print("")
                print(lose)
                print("")
                lives -= 1
            # Duplicates
            if rps == "rock" and computer == "rock":
                print("The computer chose", computer)
                print("")
                print(draw)
                print("")
                draw += 1
            if rps == "paper" and computer == "paper":
                print("The computer chose", computer)
                print("")
                print(draw)
                print("")
                draw += 1
            if rps == "scissors" and computer == "scissors":
                print("The computer chose", computer)
                print("")
                print(draw)
                print("")
                draw += 1
            # System
            if rps == 'rules':
                print("********************")
                print("Rules")
                print("********************")
                print("Rock beats scissors")
                print("Rock loses against paper")
                print("Paper beats rock")
                print("Paper loses against scissors")
                print("Scissors beats paper")
                print("Scissors loses against rock")
            if rps == "display lives":
                print(lives)
            if rps == "display score":
                print(score)
            if rps == 'display draws':
                print(draw)
            
            # Lives
            if lives == 0 or rps == 'test':
                print("Thanks for playing!")
                print("You ran out of lives or exited the game.")
                print("You won",score,"times!")
                print("You had a draw", draw, "times.")
                stop = input("Press enter to quit.")
                import time
                time.sleep(300)
            if computer_lives == 0:
                print("The computer lost all its lives. You win!")
                print("Thanks for playing.")
                print("You won",score,"times!")
                print("You had a draw", draw, "times.")
                stop = input("Press enter to quit.")
                import time
                time.sleep(300)
            # Exit
            if rps == "exit":
                break
        else:
            print("Your username or password is incorrect.")
            print(".......................................")
            
            # username: vintran
            # password: helloworld
# Out:
# To begin fill in the below information.
# Please enter your username: vintran
# Please enter your password: helloworld
# Access Granted
#
#                 _______
#             ---'   ____)
#                   (_____)
#                   (_____)
#                   (____)
#             ---.__(___)
#
#
#                  _______
#             ---'    ____)____
#                        ______)
#                       _______)
#                      _______)
#             ---.__________)
#
#
#             _______
#         ---'   ____)____
#                   ______)
#                __________)
#               (____)
#         ---.__(___)
